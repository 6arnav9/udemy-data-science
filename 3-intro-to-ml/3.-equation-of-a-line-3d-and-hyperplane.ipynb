# %% [markdown]
# # 📚 Equation of a Line, 3D Plane, and Hyperplanes in Machine Learning
#
# ---
#
# ## 1️⃣ Equation of a Line (2D)
#
# The most basic form:
# \[
# y = mx + c
# \]
#
# - **m:** Slope (steepness of the line)
# - **c:** Y-intercept (where the line crosses the y-axis)
#
# ### Vector Form:
# \[
# y = \beta_0 + \beta_1 x
# \]
#
# Or rearranged:
# \[
# ax + by + c = 0
# \]
#
# ---
#
# ## 2️⃣ Equation of a Plane (3D)
#
# In 3D, the general equation of a plane is:
# \[
# w_1 x_1 + w_2 x_2 + w_3 x_3 + b = 0
# \]
#
# ### Compact Vector Form:
# \[
# w^T x + b = 0
# \]
#
# Where:
# - \( w = \begin{bmatrix} w_1 \\ w_2 \\ w_3 \end{bmatrix} \) → Weight (normal) vector
# - \( x = \begin{bmatrix} x_1 \\ x_2 \\ x_3 \end{bmatrix} \) → Position vector
#
# ---
#
# ## 3️⃣ Hyperplane in n-Dimensions
#
# The equation extends to n dimensions:
# \[
# w_1 x_1 + w_2 x_2 + \cdots + w_n x_n + b = 0
# \]
#
# ### Compact Vector Form:
# \[
# w^T x + b = 0
# \]
#
# ---
#
# ## 4️⃣ Special Case: Hyperplane Passing Through the Origin
#
# When the hyperplane passes through the origin:
# \[
# w^T x = 0
# \]
#
# ### Key Points:
# - **w:** Always perpendicular (normal) to the hyperplane.
# - **x:** Any point lying on the hyperplane.
# - The dot product \( w^T x = |w||x|\cos \theta \)
# - For the equation to hold: \( \cos \theta = 0 \) → \( \theta = 90^\circ \)
# - This means **w and x are perpendicular only for points on the hyperplane when passing through the origin.**
#
# ---
#
# ## 🔍 Important Concept: Perpendicularity
#
# - **w is always perpendicular to the hyperplane.**
# - **w is NOT always perpendicular to all x vectors.**
# - **w is perpendicular only to those x vectors that satisfy the hyperplane equation.**
# - For the origin case (b = 0), the condition is \( w^T x = 0 \) → perpendicularity.
#
# ---
#
# ## 📐 Visualization (Mental Picture)
#
#     ↑ w vector (normal to the plane)
#     │
#     │
#
# ────────┼────────── Hyperplane (wᵀx + b = 0)
# │
# │
#
# - **w vector:** Points straight out from the plane.
# - **x vectors:** Point from the origin to locations in space.
#
# ---
#
# ## 🚀 Summary Table
#
# | Concept                  | Equation               | Key Idea                        |
# |--------------------------|------------------------|---------------------------------|
# | Line (2D)                | \( y = mx + c \)       | Slope + Intercept               |
# | Plane (3D)               | \( w^T x + b = 0 \)    | Flat surface in 3D              |
# | Hyperplane (nD)          | \( w^T x + b = 0 \)    | Generalization to n dimensions  |
# | Through Origin           | \( w^T x = 0 \)        | Passes through the origin       |
# | Perpendicularity         | Dot Product = 0        | Vectors are orthogonal          |
#
# ---
#
# ## ✅ Key Takeaways
#
# - The **hyperplane** divides the space into two parts.
# - The **w vector is always perpendicular to the hyperplane.**
# - The **x vectors** are position vectors. They may or may not lie on the hyperplane.
# - The **dot product tells us** if a point lies on the hyperplane.
# - When the hyperplane passes through the origin → **the dot product is zero** → w is perpendicular to x.
#
# ---
#
# ## 🔧 Optional: Visualize in Python (3D Plot)
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Create the hyperplane
# xx, yy = np.meshgrid(range(-10, 11), range(-10, 11))
# zz = (-2 * xx - 3 * yy) / 4  # Example: 2x + 3y + 4z + 0 = 0
#
# # Plot the plane
# fig = plt.figure(figsize=(10, 8))
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(xx, yy, zz, alpha=0.5)
#
# # Plot the normal vector (w)
# ax.quiver(0, 0, 0, 2, 3, 4, color='red', length=5)
#
# # Labels
# ax.set_xlabel('X')
# ax.set_ylabel('Y')
# ax.set_zlabel('Z')
# ax.set_title('Hyperplane and Normal Vector w')
#
# plt.show()
#
#
# ⸻
